# %% [markdown]
# <a href="https://colab.research.google.com/github/Analyticsavenue/Mega-Internship-Quick-guide/blob/main/Mega_Internship_Program_2023_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<font face="Arial" color="Red" Size = '6'><center>Mega Internship Program 2023 - 2024**</center>
# <center><b><font face="Arial" color="Blue" Size = '5'>(Opening the gateway to the field of data analytics)</center>

# %% [markdown]
# ## <font face="Arial" color="Red" Size = '6'> <B><center>Highlights</center>

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><b> 1. Eligible roles

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'><b>1. Data Analyst</b>
# <BR>
# <b>2. Data Engineer</b>
# <BR>
# <b>3. Data Consultant</b>
# <BR>
# <b>4. Visualisation Developer </b>
# <BR>
# <b>5. Tech Support Engineer</b>
# <BR>
# <b>6. Junior Data Scientist</b>

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><b>2.  Average Salary Package

# %% [markdown]
# <font face="Arial" color="Black" Size = '5'>
# <b>
# 5L - 12L / PA
# </b>

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><B>3. Top 10 Analytical companies targeted

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'>
# <B>
# 1. Amazon <BR>
# 2. Flipcart <BR>
# 3. Shopify <BR>
# 4. Adobe <BR>
# 5. FIS <Br>
# 6. Citi <BR>
# 7. Tiger Analytcis <BR>
# 8. Latentview Analytics <BR>
# 9.Zoho <BR>
# 10.Delloite<BR>
# 11. Orion <BR>
# 12. CTS <BR>
# 13. TCS <BR>
# 13. Infosys <BR>
# 14. Fractal analytics
# 15. Fresh works
#
# Note: You can even apply for similar organisations as mentioned above | We also share you other HR email ids to apply but no where we assure you for confirmed placements once you are skillful getting job wont be a big deal!

# %% [markdown]
# ![Projects (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><B>4. Internship Significance

# %% [markdown]
# ![Data Analytics PPT.png](data:image/png;base64,...)

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'><B>
# 1. Internship tasks <br>
# 2. 2 Real time project (Finance /Ecommerce / Marketing analytics and Automotives) <br>
# 3. Solving 100+ Intreview questions <br>
# 4. In touch with real time data scientist and data engineers (5+ yrs of experience) <br>
# 5. Digital notes <br>
# 6. Internship Certificate

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><B>5. My projects

# %% [markdown]
# ![Projects.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><B>6. Session Duration

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'><B> Each and every technology involves 3 - 4 months time period <BR>
# Session Timing:<br>
# Saturday :  6:00 PM - 7:30 PM <br>
# Sunday 11:30 PM - 1:00 PM / 2:30 PM - 4:00 PM  / 6:30 PM - 8:00 PM

# %% [markdown]
# <br>

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'><B>
# We will be conducting various placement activities at an interval of 45 days in Anna Cnetenary library for a direct interaction italicized text

# %% [markdown]
# #<font face="Arial" color="Blue" Size = '6'><B>7. Confirmation Form

# %% [markdown]
# <font face="Arial" color="Black" Size = '4'><B>Initially will have 2 free session post that should block the seats in that upcoming week
#
# <br>Note: Fee once paid will not be refunded after 5 sessions
#
# https://forms.gle/roaZuVs2PyzBjgSq9
